# %% [markdown]
# ## **Evaluación Late Fusion en *split* de Validación**

# %% [markdown]
# Se muestran y analizan los resultados obtenidos del rendimiento de los modelos con la estrategia de **Late Fusion** en el *split* de validación con los **backbones** seleccionados en la fase previa (*early fusion*):
#
# `resnet32_wav2vec11s_berta64` (Modelo que representa **Máximo Rendimiento**):
#
# * **Backbone Vídeo**: **ResNet50**.
#
# * **Backbone Audio:**: **Wav2Vec 2.0**.
#
# * **Backbone Texto**: **BERT**.
#
# `efficientnet32_mfcc11s_berta64` (Modelo que representa **Alta Eficiencia**):
#
# * **Backbone Vídeo**: **EfficientNet-B0**.
#
# * **Backbone Audio:**: **MFCCs+RMS+ZCR (*handcrafted*)**.
#
# * **Backbone Texto**: **BERT**.

# %%
# Carga de librerías:
from IPython.display import Image, display

# %% [markdown]
# * Primer modelo con **backbones** de Máximo Rendimiento: `resnet32_wav2vec11s_berta64`

# %%
ruta_reporte = "../resultados/resultados_dev_latefusion/reporte_final_dev_modelo_late_resnet32_wav2vec11s_bert64.txt"
with open(ruta_reporte, 'r', encoding='utf-8') as f:
    print(f.read())

ruta_matriz = "../resultados/resultados_dev_latefusion/Fig_6_1_1_matriz_confusion_modelo_dev_late_resnet32_wav2vec11s_bert64.png"
ruta_roc = "../resultados/resultados_dev_latefusion/Fig_6_1_2_curva_roc_modelo_dev_late_resnet32_wav2vec11s_bert64.png"

display(Image(filename=ruta_matriz, width=5000))

display(Image(filename=ruta_roc, width=5000))
# Out:
# MODELO: ./modelo_estres_late_resnet32_wav2vec11s_bert64.pth
# Parámetros: 9257731
# Inferencia media: 4.81 ms
# ROC-AUC: 0.8125
#               precision    recall  f1-score   support
#
#    No Estrés     0.8321    0.7381    0.7823      1638
#       Estrés     0.6398    0.7575    0.6937      1006
#
#     accuracy                         0.7455      2644
#    macro avg     0.7359    0.7478    0.7380      2644
# weighted avg     0.7589    0.7455    0.7486      2644

# %% [markdown]
# * Segundo modelo con **backbones** de Alta Eficiencia: `efficientnet32_mfcc11s_berta64`

# %%
ruta_reporte = "../resultados/resultados_dev_latefusion/reporte_final_dev_modelo_late_efficientnet32_mfcc11s_bert64.txt"
with open(ruta_reporte, 'r', encoding='utf-8') as f:
    print(f.read())

ruta_matriz = "../resultados/resultados_dev_latefusion/Fig_6_1_1_matriz_confusion_modelo_dev_late_efficientnet32_mfcc11s_bert64.png"
ruta_roc = "../resultados/resultados_dev_latefusion/Fig_6_1_2_curva_roc_modelo_dev_late_efficientnet32_mfcc11s_bert64.png"

display(Image(filename=ruta_matriz, width=5000))

display(Image(filename=ruta_roc, width=5000))
# Out:
# MODELO: ./modelo_estres_late_efficientnet32_mfcc11s_bert64.pth
# Parámetros: 4936195
# Inferencia media: 1.02 ms
# ROC-AUC: 0.8168
#               precision    recall  f1-score   support
#
#    No Estrés     0.8349    0.6947    0.7584      1638
#       Estrés     0.6097    0.7763    0.6830      1006
#
#     accuracy                         0.7258      2644
#    macro avg     0.7223    0.7355    0.7207      2644
# weighted avg     0.7492    0.7258    0.7297      2644

# %% [markdown]
# ## **Evaluación Attention Fusion en *split* de Validación**

# %% [markdown]
# Se muestran y analizan los resultados obtenidos del rendimiento de los modelos con la estrategia de **Attention Fusion** en el *split* de validación con los **backbones** seleccionados en la fase previa (*early fusion*):
#
# * `resnet32_wav2vec11s_berta64` (Modelo que representa **Máximo Rendimiento**):

# %%
ruta_reporte = "../resultados/resultados_dev_attention/reporte_final_dev_modelo_attention_resnet32_wav2vec11s_bert64.txt"
with open(ruta_reporte, 'r', encoding='utf-8') as f:
    print(f.read())

ruta_matriz = "../resultados/resultados_dev_attention/Fig_6_1_1_matriz_confusion_modelo_dev_attention_resnet32_wav2vec11s_bert64.png"
ruta_roc = "../resultados/resultados_dev_attention/Fig_6_1_2_curva_roc_modelo_dev_attention_resnet32_wav2vec11s_bert64.png"

display(Image(filename=ruta_matriz, width=5000))

display(Image(filename=ruta_roc, width=5000))
# Out:
# MODELO: ./modelo_estres_attention_resnet32_wav2vec11s_bert64.pth
# Parámetros: 9191938
# Inferencia media: 4.92 ms
# ROC-AUC: 0.8356
#               precision    recall  f1-score   support
#
#    No Estrés     0.8776    0.6783    0.7652      1638
#       Estrés     0.6176    0.8459    0.7139      1006
#
#     accuracy                         0.7421      2644
#    macro avg     0.7476    0.7621    0.7395      2644
# weighted avg     0.7786    0.7421    0.7457      2644

# %% [markdown]
# * `efficientnet32_mfcc11s_berta64` (Modelo que representa **Alta Eficiencia**):

# %%
ruta_reporte = "../resultados/resultados_dev_attention/reporte_final_dev_modelo_attention_efficientnet32_mfcc11s_bert64.txt"
with open(ruta_reporte, 'r', encoding='utf-8') as f:
    print(f.read())

ruta_matriz = "../resultados/resultados_dev_attention/Fig_6_1_1_matriz_confusion_modelo_dev_attention_efficientnet32_mfcc11s_bert64.png"
ruta_roc = "../resultados/resultados_dev_attention/Fig_6_1_2_curva_roc_modelo_dev_attention_efficientnet32_mfcc11s_bert64.png"

display(Image(filename=ruta_matriz, width=5000))

display(Image(filename=ruta_roc, width=5000))
# Out:
# MODELO: ./modelo_estres_attention_efficientnet32_mfcc11s_bert64.pth
# Parámetros: 4870402
# Inferencia media: 1.05 ms
# ROC-AUC: 0.8130
#               precision    recall  f1-score   support
#
#    No Estrés     0.8096    0.7711    0.7899      1638
#       Estrés     0.6541    0.7048    0.6785      1006
#
#     accuracy                         0.7458      2644
#    macro avg     0.7318    0.7379    0.7342      2644
# weighted avg     0.7504    0.7458    0.7475      2644
